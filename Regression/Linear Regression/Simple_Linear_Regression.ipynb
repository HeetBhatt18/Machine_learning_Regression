# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hb292\OneDrive\Desktop\Projects\Supersvised Machine learning\Regression\Linear Regression\Salary.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465

# %%
df.isnull()
# Out:
#     YearsExperience  Salary
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False
# 6             False   False
# 7             False   False
# 8             False   False
# 9             False   False
# 10            False   False
# 11            False   False
# 12            False   False
# 13            False   False
# 14            False   False
# 15            False   False
# 16            False   False
# 17            False   False
# 18            False   False
# 19            False   False
# 20            False   False
# 21            False   False
# 22            False   False
# 23            False   False
# 24            False   False
# 25            False   False
# 26            False   False
# 27            False   False
# 28            False   False
# 29            False   False
# 30            False   False
# 31            False   False
# 32            False   False
# 33            False   False
# 34            False   False

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5],
#        [11.2],
#        [11.5],
#        [12.3],
#        [12.9],
#        [13.5]])

# %%
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872, 127345, 126756,
#        128765, 135675, 139465])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train
# Out:
# array([[13.5],
#        [ 1.1],
#        [11.5],
#        [ 3.2],
#        [ 2.9],
#        [ 9. ],
#        [12.3],
#        [ 6. ],
#        [ 5.3],
#        [ 3. ],
#        [ 5.9],
#        [10.3],
#        [ 3.9],
#        [ 3.7],
#        [ 4. ],
#        [ 9.6],
#        [12.9],
#        [ 5.1],
#        [ 9.5],
#        [ 7.1],
#        [ 1.5],
#        [ 3.2],
#        [ 1.3],
#        [ 6.8],
#        [ 7.9],
#        [ 8.2],
#        [10.5],
#        [ 2. ]])

# %%
X_test
# Out:
# array([[ 2.2],
#        [ 4. ],
#        [ 4.5],
#        [ 4.9],
#        [11.2],
#        [ 8.7],
#        [ 4.1]])

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
accuracy = lr.score(X_test, Y_test)
print(accuracy*100, '%')
# Out:
# 93.28501842568441 %

# %%
plt.scatter(X_train, Y_train, color = 'red')
plt.plot(X_train, lr.predict(X_train), color = 'blue')


# Visualising the Test set results
plt.scatter(X_test, Y_test, color = 'red')
plt.plot(X_train, lr.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
